# %% [markdown]
# # Exploratory Data Analysis on Nutrition Data
#
# ##Exploratory data analysis (EDA) includes using graphics and visualizations to explore and analyze a dataset. This way summerizing the datasets main characteristics, often with visual methods becomes possible.

# %%
import warnings; warnings.simplefilter('ignore')
from IPython.display import Image
# !wget https://cdn.shopify.com/s/files/1/2678/2854/files/nutrition-email-title.gif
Image(open('/content/nutrition-email-title.gif','rb').read())
# Out:
# --2024-10-09 13:58:25--  https://cdn.shopify.com/s/files/1/2678/2854/files/nutrition-email-title.gif
# Resolving cdn.shopify.com (cdn.shopify.com)... 23.227.60.200, 2620:127:f00f:ff01::
# Connecting to cdn.shopify.com (cdn.shopify.com)|23.227.60.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 739712 (722K) [image/gif]
# Saving to: ‘nutrition-email-title.gif.1’
#
# nutrition-email-tit 100%[===================>] 722.38K  --.-KB/s    in 0.02s
#
# 2024-10-09 13:58:26 (35.9 MB/s) - ‘nutrition-email-title.gif.1’ saved [739712/739712]

# %% [markdown]
# ### Data Collections

# %% [markdown]
# #### Here, Nutrition datasets were used because they are standard datasets for exploratory data analysis. The datasets are also numerical. Hence, the datasets are downloaded using **!wget** command.

# %%
# !wget "https://storage.googleapis.com/kaggle-data-sets/3461748/6050985/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20241009%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241009T123326Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..." -O "nutritionArchive.zip"
# Out:
# --2024-10-09 13:58:26--  https://storage.googleapis.com/kaggle-data-sets/3461748/6050985/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20241009%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241009T123326Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.31.207, 142.251.111.207, 142.251.179.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.31.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3224439 (3.1M) [application/zip]
# Saving to: ‘nutritionArchive.zip’
#
# nutritionArchive.zi 100%[===================>]   3.07M  --.-KB/s    in 0.03s
#
# 2024-10-09 13:58:26 (89.1 MB/s) - ‘nutritionArchive.zip’ saved [3224439/3224439]

# %% [markdown]
# ### Importing Libraries

# %% [markdown]
# #### Required libraries and modules for exploratory data Analysis are loaded.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ### Loading dataset as a pandas dataframe.

# %% [markdown]
# #### Then datasets are loaded using **"pd.read_csv(CSV-path)"**  command.

# %%
import os
# !pip install patool==1.12  # Install patool library
import patoolib

if not os.path.exists('/content/nutrition.xlsx'):
    patoolib.extract_archive("/content/nutritionArchive.zip", outdir="/content")
    print("nutrition.xlsx was not found, so the archive was extracted.")
else:
    print("nutrition.xlsx already exists, skipping extraction.")
# Out:
# Requirement already satisfied: patool==1.12 in /usr/local/lib/python3.10/dist-packages (1.12)
# patool: Extracting /content/nutritionArchive.zip ...
# patool: running /usr/bin/7z x -o/content -- /content/nutritionArchive.zip
# patool: ... /content/nutritionArchive.zip extracted to `/content'.
# '/content'

# %%
Datapath = "/content/nutrition.xlsx"

df = pd.read_excel(Datapath)
# Let's display the top 8 rows
df.head(8)
# Out:
#    Unnamed: 0               name serving_size  calories total_fat  \
# 0           0         Cornstarch        100 g       381      0.1g
# 1           1       Nuts, pecans        100 g       691       72g
# 2           2      Eggplant, raw        100 g        25      0.2g
# 3           3     Teff, uncooked        100 g       367      2.4g
# 4           4    Sherbet, orange        100 g       144        2g
# 5           5   Cauliflower, raw        100 g        25      0.3g
# 6           6   Taro leaves, raw        100 g        42      0.7g
# 7           7  Lamb, raw, ground        100 g       282       23g
#
#   saturated_fat cholesterol    sodium  choline      folate  ...      fat  \
# 0           NaN           0   9.00 mg   0.4 mg    0.00 mcg  ...   0.05 g
# 1          6.2g           0   0.00 mg  40.5 mg   22.00 mcg  ...  71.97 g
# 2           NaN           0   2.00 mg   6.9 mg   22.00 mcg  ...   0.18 g
# 3          0.4g           0  12.00 mg  13.1 mg           0  ...   2.38 g
# 4          1.2g         1mg  46.00 mg   7.7 mg    4.00 mcg  ...   2.00 g
# 5          0.1g           0  30.00 mg  44.3 mg   57.00 mcg  ...   0.28 g
# 6          0.2g           0   3.00 mg  12.8 mg  126.00 mcg  ...   0.74 g
# 7           10g        73mg  59.00 mg  69.3 mg   18.00 mcg  ...  23.41 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
# 5               0.130 g                     0.034 g
# 6               0.151 g                     0.060 g
# 7              10.190 g                     9.600 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
# 5                     0.031 g                 0.00 mg   0.0 g  0.76 g
# 6                     0.307 g                 0.00 mg   0.0 g  1.92 g
# 7                     1.850 g                73.00 mg   0.0 g  0.87 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
# 5  0.00 mg     0.00 mg  92.07 g
# 6  0.00 mg     0.00 mg  85.66 g
# 7  0.00 mg     0.00 mg  59.47 g
#
# [8 rows x 77 columns]

# %% [markdown]
# ### Data checking

# %% [markdown]
# #### Then let's check the eight last rows of the datasets.

# %%
df.tail(8)
# Out:
#       Unnamed: 0                                               name  \
# 8781        8781  Beef, raw, choice, trimmed to 1/8" fat, separa...
# 8782        8782  Oil, uses similar to 95 degree hard butter, co...
# 8783        8783  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8784        8784  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8785        8785  Lamb, cooked, separable lean only, composite o...
# 8786        8786  Lamb, raw, separable lean and fat, composite o...
# 8787        8787  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8788        8788  Beef, raw, all grades, trimmed to 0" fat, sepa...
#
#      serving_size  calories total_fat saturated_fat cholesterol    sodium  \
# 8781        100 g       161      8.3g          3.1g        63mg  56.00 mg
# 8782        100 g       884      100g           94g           0   6.00 mg
# 8783        100 g       124      3.3g          1.3g        62mg  54.00 mg
# 8784        100 g       125      3.5g          1.4g        62mg  54.00 mg
# 8785        100 g       206      8.9g          3.9g       109mg  50.00 mg
# 8786        100 g       277       23g           12g        78mg  39.00 mg
# 8787        100 g       121        3g          1.1g        60mg  53.00 mg
# 8788        100 g       121        3g          1.1g        60mg  53.00 mg
#
#       choline    folate  ...       fat saturated_fatty_acids  \
# 8781  47.9 mg  3.00 mcg  ...    8.29 g               3.057 g
# 8782   0.2 mg  0.00 mcg  ...  100.00 g              93.701 g
# 8783  64.6 mg  4.00 mcg  ...    3.34 g               1.287 g
# 8784  64.5 mg  4.00 mcg  ...    3.50 g               1.353 g
# 8785        0  0.00 mcg  ...    8.86 g               3.860 g
# 8786        0  1.00 mcg  ...   22.74 g              11.570 g
# 8787  64.2 mg  4.00 mcg  ...    3.04 g               1.086 g
# 8788  64.2 mg  4.00 mcg  ...    3.04 g               1.086 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 8781                     3.576 g                     0.467 g
# 8782                     0.257 g                     0.000 g
# 8783                     1.481 g                     0.238 g
# 8784                     1.554 g                     0.244 g
# 8785                     3.480 g                     0.520 g
# 8786                     8.720 g                     0.980 g
# 8787                     1.266 g                     0.233 g
# 8788                     1.266 g                     0.233 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 8781                63.00 mg   0.0 g  0.99 g  0.00 mg     0.00 mg  69.65 g
# 8782                 0.00 mg   0.0 g  0.01 g  0.00 mg     0.00 mg   0.05 g
# 8783                62.00 mg   0.0 g  1.12 g  0.00 mg     0.00 mg  72.64 g
# 8784                62.00 mg   0.0 g  1.11 g  0.00 mg     0.00 mg  72.51 g
# 8785               109.00 mg       0  1.60 g        0           0  59.95 g
# 8786                78.00 mg       0  0.92 g        0           0  59.80 g
# 8787                60.00 mg   0.0 g  1.10 g  0.00 mg     0.00 mg  73.43 g
# 8788                60.00 mg   0.0 g  1.10 g  0.00 mg     0.00 mg  73.43 g
#
# [8 rows x 77 columns]

# %% [markdown]
# #### One of the important matters in data analysis is knowing data types.
# #### This can be implemented easily by **"df.dtypes"**.

# %% [markdown]
# ###  Data processing

# %% [markdown]
# #### Droping unnecessary data are necessary for any EDA. But in this tutorial, we will save it to a dataframe called **dfDroped**.

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# name            object
# serving_size    object
# calories         int64
# total_fat       object
#                  ...
# alcohol         object
# ash             object
# caffeine        object
# theobromine     object
# water           object
# Length: 77, dtype: object

# %%
dfDroped = df.drop(['ash'], axis=1).copy(deep=True)
dfDroped.head(4)
# Out:
#    Unnamed: 0            name serving_size  calories total_fat saturated_fat  \
# 0           0      Cornstarch        100 g       381      0.1g           NaN
# 1           1    Nuts, pecans        100 g       691       72g          6.2g
# 2           2   Eggplant, raw        100 g        25      0.2g           NaN
# 3           3  Teff, uncooked        100 g       367      2.4g          0.4g
#
#   cholesterol    sodium  choline     folate  ... sucrose      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...       0   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  3.90 g  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...  0.26 g   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...  0.62 g   2.38 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol caffeine  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.00 mg
# 1                    21.614 g                 0.00 mg   0.0 g  0.00 mg
# 2                     0.076 g                 0.00 mg   0.0 g  0.00 mg
# 3                     1.071 g                       0       0        0
#
#   theobromine    water
# 0     0.00 mg   8.32 g
# 1     0.00 mg   3.52 g
# 2     0.00 mg  92.30 g
# 3           0   8.82 g
#
# [4 rows x 76 columns]

# %% [markdown]
# #### In the next phase, how to drop duplicated columns will be shown.

# %% [markdown]
# #### Hence let's add a column to a dataframe and call it **dfDuplicated**.

# %%
dfDuplicated=df.copy(deep=True)
dfDuplicated['ash']=df.loc[:,'ash']

print("👇 Please check the last column that \" ash \" is added  👇 \n" )
dfDuplicated.head(6)
# Out:
# 👇 Please check the last column that " ash " is added  👇
#    Unnamed: 0              name serving_size  calories total_fat  \
# 0           0        Cornstarch        100 g       381      0.1g
# 1           1      Nuts, pecans        100 g       691       72g
# 2           2     Eggplant, raw        100 g        25      0.2g
# 3           3    Teff, uncooked        100 g       367      2.4g
# 4           4   Sherbet, orange        100 g       144        2g
# 5           5  Cauliflower, raw        100 g        25      0.3g
#
#   saturated_fat cholesterol    sodium  choline     folate  ...      fat  \
# 0           NaN           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1          6.2g           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           NaN           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3          0.4g           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4          1.2g         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
# 5          0.1g           0  30.00 mg  44.3 mg  57.00 mcg  ...   0.28 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
# 5               0.130 g                     0.034 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
# 5                     0.031 g                 0.00 mg   0.0 g  0.76 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
# 5  0.00 mg     0.00 mg  92.07 g
#
# [6 rows x 77 columns]

# %% [markdown]
# #### Then let's correct "**dfDuplicated**" and make a new dataframe called "**CorrecteddfDuplicated**".

# %%
def drop_duplicate_cols(df):
    df = df.T.drop_duplicates().T
    return df
print("The shape of duplicate columns: ", dfDuplicated.shape)
print('\n')

CorrecteddfDuplicated=drop_duplicate_cols(dfDuplicated).copy(deep=True)
print("The shape of corrected  columns: ", CorrecteddfDuplicated.shape,'\n\n')
print("👇 Please check the last column \" ash \" is removed 👇 \n" )
CorrecteddfDuplicated.head(6)
# Out:
# The shape of duplicate columns:  (8789, 77)
#
#
# The shape of corrected  columns:  (8789, 76)
#
#
# 👇 Please check the last column " ash " is removed 👇
#   Unnamed: 0              name serving_size calories total_fat saturated_fat  \
# 0          0        Cornstarch        100 g      381      0.1g           NaN
# 1          1      Nuts, pecans        100 g      691       72g          6.2g
# 2          2     Eggplant, raw        100 g       25      0.2g           NaN
# 3          3    Teff, uncooked        100 g      367      2.4g          0.4g
# 4          4   Sherbet, orange        100 g      144        2g          1.2g
# 5          5  Cauliflower, raw        100 g       25      0.3g          0.1g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
# 5           0  30.00 mg  44.3 mg  57.00 mcg  ...   0.28 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
# 5               0.130 g                     0.034 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
# 5                     0.031 g                 0.00 mg   0.0 g  0.76 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
# 5  0.00 mg     0.00 mg  92.07 g
#
# [6 rows x 76 columns]

# %% [markdown]
# #### Now we are going to count the number of rows and columns.
# "**df.count(axis='columns')**" Counts for each row, while "**df.count(axis='rows')**"counts number of columns.
#
# Reference: ☛ https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html

# %%
print("\033[1mBelow is the number of rows\n")
print(df.count(axis='columns'))
print( "\n\033[1mBelow is the number of columns\n")
df.count(axis='rows')
# Out:
# Below is the number of rows
#
# 0       76
# 1       77
# 2       76
# 3       77
# 4       77
#         ..
# 8784    77
# 8785    77
# 8786    77
# 8787    77
# 8788    77
# Length: 8789, dtype: int64
#
# Below is the number of columns
# Unnamed: 0      8789
# name            8789
# serving_size    8789
# calories        8789
# total_fat       8789
#                 ...
# alcohol         8789
# ash             8789
# caffeine        8789
# theobromine     8789
# water           8789
# Length: 77, dtype: int64

# %% [markdown]
# #### Sometimes, it is necessary to process the data before analysing them.
# #### One of these processes is removing "nan", "null", and "none" entries from a dataset.

# %% [markdown]
# #### Check if there is a null
# #### **".isnull().sum()"** command shows that there is no missing value in each column.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# name            0
# serving_size    0
# calories        0
# total_fat       0
#                ..
# alcohol         0
# ash             0
# caffeine        0
# theobromine     0
# water           0
# Length: 77, dtype: int64

# %% [markdown]
# #### Using **".isnull().sum()"**, it is apparent that there is no "nan" value in each column.

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# name            0
# serving_size    0
# calories        0
# total_fat       0
#                ..
# alcohol         0
# ash             0
# caffeine        0
# theobromine     0
# water           0
# Length: 77, dtype: int64

# %% [markdown]
# #### Let's randomly insert "nan" in different locations of the datafram of dataframe "**df**" and call it a new dataframe "**dfWithNan**".

# %%
dfWithNan = df.copy(deep=True)
for col in dfWithNan.columns:
    dfWithNan.loc[dfWithNan.sample(frac=0.1).index, col] = np.nan


dfWithNan.head(5)
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0         0.0       Cornstarch        100 g     381.0      0.1g           NaN
# 1         1.0              NaN        100 g     691.0       72g          6.2g
# 2         2.0              NaN        100 g      25.0      0.2g           NaN
# 3         3.0   Teff, uncooked          NaN     367.0      2.4g          0.4g
# 4         4.0  Sherbet, orange        100 g     144.0        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0         NaN   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 77 columns]

# %% [markdown]
# #### Now, it is clear that there are 160 missing data in each column.

# %%
dfWithNan.isna().sum()
# Out:
# Unnamed: 0      879
# name            879
# serving_size    879
# calories        879
# total_fat       879
#                ...
# alcohol         879
# ash             879
# caffeine        879
# theobromine     879
# water           879
# Length: 77, dtype: int64

# %% [markdown]
# #### Next, we are going to remove the missing entries.

# %%
# dfWithNan['column name'].isna().sum()
print("\033[1mnumber of \"Nan\" in each columns\n")
print(dfWithNan.isna().sum())
print("\n\033[mnumber of \"Nan\" in index \"0\" rows\n")
print("\033[",dfWithNan.loc[[0]].isna().sum().sum(),'\n')
dfDropedNA = dfWithNan.dropna().copy(deep=True)    # Dropping the missing values.
print("\033[1mnumber of \"Nan\" in each columns\n")
print(dfDropedNA.isna().sum())
print("\n\033[mnumber of \"Nan\" in index \"0\" row of proccessed dataframe. 👇\n")

## Let's add the base class for all built-in exceptions

try:
  print("\033[",dfDropedNA.loc[[0]].isna().sum().sum(),'\n')
except BaseException :
  print("No Nan were found in each row")
# Out:
# number of "Nan" in each columns
#
# Unnamed: 0      879
# name            879
# serving_size    879
# calories        879
# total_fat       879
#                ...
# alcohol         879
# ash             879
# caffeine        879
# theobromine     879
# water           879
# Length: 77, dtype: int64
#
# number of "Nan" in index "0" rows
#
# [ 9
#
# number of "Nan" in each columns
#
# Unnamed: 0      0
# name            0
# serving_size    0
# calories        0
# total_fat       0
#                ..
# alcohol         0
# ash             0
# caffeine        0
# theobromine     0
# water           0
# Length: 77, dtype: int64
#
# number of "Nan" in index "0" row of proccessed dataframe. 👇
#
# No Nan were found in each row

# %% [markdown]
# #### As you can see, no nan was found in each row. This shows that nan data are entirely removed.

# %%
dfDropedNA.head(8)
# Out:
#       Unnamed: 0                                               name  \
# 8259      8259.0  Beef, grilled, cooked, all grades, trimmed to ...
#
#      serving_size  calories total_fat saturated_fat cholesterol    sodium  \
# 8259        100 g     223.0       11g          4.5g        81mg  59.00 mg
#
#       choline    folate  ...      fat saturated_fatty_acids  \
# 8259  67.4 mg  7.00 mcg  ...  11.15 g               4.534 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 8259                     5.081 g                     0.578 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 8259                81.00 mg   0.0 g  1.12 g  0.00 mg     0.00 mg  59.98 g
#
# [1 rows x 77 columns]

# %% [markdown]
# ### Descriptive Statistics
# ### (Now one of the most exciting parts begins)

# %% [markdown]
# #### Descriptive statistics can give you great insight into the shape of each attribute.
# Sometimes it is necessary to check the summary of the data. The "describe()" function on the Pandas dataframe lists eight statistical properties of each attribute:
#
# a). Count
#
# b). Mean
#
# c). Standard Deviation
#
# d). Minimum Value
#
# e). 25th Percentile
#
# f). 50th Percentile (Median)
#
# g). 75th Percentile
#
# h). Maximum Value

# %%
df.describe()
# Out:
#         Unnamed: 0     calories  lucopene
# count  8789.000000  8789.000000    8789.0
# mean   4394.000000   226.283878       0.0
# std    2537.310091   169.862001       0.0
# min       0.000000     0.000000       0.0
# 25%    2197.000000    91.000000       0.0
# 50%    4394.000000   191.000000       0.0
# 75%    6591.000000   337.000000       0.0
# max    8788.000000   902.000000       0.0

# %% [markdown]
# ### Heatmap (Data correlation)

# %% [markdown]
# #### In this section, we will calculate the correlation between the componets of red nutrition using a heatmap, seaborn.

# %% [markdown]
# ### The units from the data will be removed to convert data type to floating points

# %%
import re

def remove_units(value):
    """Removes units (g, mg, mcg) from values and returns the numerical part."""
    match = re.search(r'([\d.]+)', str(value))  # Extract numerical part
    if match:
        return float(match.group(1))  # Convert to float
    else:
        return np.nan  # Handle cases without numerical part as NaN

# Apply the function to the DataFrame
for column in  df.columns[2:]:
    df[column] = df[column].apply(remove_units)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.iloc[:, 2:9].corr(),cbar=True,annot=True,cmap='Purples_r')
# Out:
# <Axes: >

# %% [markdown]
# ### Count Plot

# %% [markdown]
# #### Now, let’s do a count plot to visualize the above data
# #### Count Plot shows the count of observations in each categorical bin, using bars instead of a quantitative variable, like a histogram.

# %%
## Let's set a background for the plot.
sns.set_theme(style="whitegrid")

sns.countplot(x='saturated_fat', data=df.iloc[1:30, :])
# Out:
# <Axes: xlabel='saturated_fat', ylabel='count'>

# %% [markdown]
# ### Histogram

# %% [markdown]
# #### A histogram shoes statistical information that utilizes rectangles to illustrate the frequency of data items in successive numerical intervals of equal size.

# %%
df.iloc[:, 3:12].hist(bins=20, figsize=(4,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Pairs plot

# %% [markdown]
# #### A pairs plot shows pairwise relationships in a dataset. In addition, it provides a square subplot with a histogram in the main dimeter (each data by itself), and a scatter plot elsewhere.

# %%
plt.figure(figsize=(10, 8))
sns.pairplot(df.iloc[:, 3:9], hue="saturated_fat", palette="husl")
plt.plot()
# Out:
# []

# %% [markdown]
# ### Box Plot

# %% [markdown]
# #### The following plot shows a box plot of the quality versus other data. The box shows the quartiles of the dataset while the whiskers (like a line) extend to show the rest of the distribution, except for points that are determined to be “outliers” using a function method of the interquartile range.
#
#
# reference:👉 https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn-boxplot
#
# #### The below plots show the interpertaions of the box plot.

# %% [markdown]
# ![Picture5Summeris.jpg](data:image/jpeg;base64,...)

# %%
for i in df.columns[4:8]:
    plt.figure()
    sns.boxplot(x=df['sodium'][:10], y=df[i][:10])  # Slice data for first 10 rows
    plt.plot()

# %% [markdown]
# ####Outliers can be visualized using a "box plot."
# #### Any points outside of the maximum and minimum value are considered an outlier.

# %%
sns.boxplot(x=df['sodium'][:30]) #  first 30 rows
# Out:
# <Axes: xlabel='sodium'>

# %%
df.head(5)
# Out:
#    Unnamed: 0             name  serving_size  calories  total_fat  \
# 0           0       Cornstarch         100.0     381.0        0.1
# 1           1     Nuts, pecans         100.0     691.0       72.0
# 2           2    Eggplant, raw         100.0      25.0        0.2
# 3           3   Teff, uncooked         100.0     367.0        2.4
# 4           4  Sherbet, orange         100.0     144.0        2.0
#
#    saturated_fat  cholesterol  sodium  choline  folate  ...    fat  \
# 0            NaN          0.0     9.0      0.4     0.0  ...   0.05
# 1            6.2          0.0     0.0     40.5    22.0  ...  71.97
# 2            NaN          0.0     2.0      6.9    22.0  ...   0.18
# 3            0.4          0.0    12.0     13.1     0.0  ...   2.38
# 4            1.2          1.0    46.0      7.7     4.0  ...   2.00
#
#    saturated_fatty_acids  monounsaturated_fatty_acids  \
# 0                  0.009                        0.016
# 1                  6.180                       40.801
# 2                  0.034                        0.016
# 3                  0.449                        0.589
# 4                  1.160                        0.530
#
#    polyunsaturated_fatty_acids  fatty_acids_total_trans  alcohol   ash  \
# 0                        0.025                      0.0      0.0  0.09
# 1                       21.614                      0.0      0.0  1.49
# 2                        0.076                      0.0      0.0  0.66
# 3                        1.071                      0.0      0.0  2.37
# 4                        0.080                      1.0      0.0  0.40
#
#    caffeine  theobromine  water
# 0       0.0          0.0   8.32
# 1       0.0          0.0   3.52
# 2       0.0          0.0  92.30
# 3       0.0          0.0   8.82
# 4       0.0          0.0  66.10
#
# [5 rows x 77 columns]

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# #### A scatter plot shows the relationship between two quantitative variables and provides a point by point data on two (x and y) axis.

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['calories'], df['total_fat'])
ax.set_xlabel('calories')
ax.set_ylabel('total_fat')
plt.show()

# %%
import warnings; warnings.simplefilter('ignore')
from IPython.display import Image

# !wget https://www.funimada.com/assets/images/cards/big/congrats-7.gif
Image(open('/content/congrats-7.gif','rb').read())
# Out:
# --2024-10-09 14:22:05--  https://www.funimada.com/assets/images/cards/big/congrats-7.gif
# Resolving www.funimada.com (www.funimada.com)... 46.4.34.162
# Connecting to www.funimada.com (www.funimada.com)|46.4.34.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1417466 (1.4M) [image/gif]
# Saving to: ‘congrats-7.gif.1’
#
# congrats-7.gif.1    100%[===================>]   1.35M  2.41MB/s    in 0.6s
#
# 2024-10-09 14:22:06 (2.41 MB/s) - ‘congrats-7.gif.1’ saved [1417466/1417466]

# %% [markdown]
# ### Congratulations, you completed Exploratory Data Analysis (EDA) successfully.
